# %%
import pandas as pd
import os
from collections import Counter

# %%
os.chdir("/home/david/dev/fastapi-sqlalchemy/tests")

# %%
df = pd.read_csv("./Utilisation report - 20230227.xlsx - TimeByTask.csv", usecols=[0,2,5,7,9], header=0)
df
# Out:
#                   [Job] Client                          [Job] Name
# 0            AlphaCert Limited         ALPH-2136 ACC AWS Discovery  \
# 1            AlphaCert Limited         ALPH-2136 ACC AWS Discovery
# 2            AlphaCert Limited         ALPH-2136 ACC AWS Discovery
# 3            AlphaCert Limited          ALPH-2137 DevOps Engineer
# 4            AlphaCert Limited          ALPH-2137 DevOps Engineer
# ...                        ...                                 ...
# 5051  Woolworths Group Limited  WWAU-XXXX Client Non-Billable Work
# 5052  Woolworths Group Limited  WWAU-XXXX Client Non-Billable Work
# 5053  Woolworths Group Limited  WWAU-XXXX Client Non-Billable Work
# 5054  Woolworths Group Limited  WWAU-XXXX Client Non-Billable Work
# 5055  Woolworths Group Limited  WWAU-XXXX Client Non-Billable Work
#
#          [Staff] Name [Time] Date  [Time] Time (Totalled)
# 0       Terence White   30-Jan-23                    1.00
# 1       Terence White   31-Jan-23                    1.00
# 2       Terence White   10-Feb-23                    0.25
# 3     Alexey Pavlenko    1-Feb-23                    8.00
# 4     Alexey Pavlenko    2-Feb-23                    8.00
# ...               ...         ...                     ...
# 5051   Mina Al-Ansari    8-Feb-23                    1.00
# 5052   Mina Al-Ansari    9-Feb-23                    1.00
# 5053   Mina Al-Ansari   10-Feb-23                    2.00
# 5054   Mina Al-Ansari   14-Feb-23                    2.00
# 5055   Mina Al-Ansari   17-Feb-23                    1.00
#
# [5056 rows x 5 columns]

# %%
clients = list(df["[Job] Client"].loc[:])
clients
# Out:
# ['AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'AlphaCert Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'Apex Investment Administration (NZ) Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'ASB Bank Limited',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'AskNicely',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'Author-it Software Corporation Limited',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  'ClearPoint ',
#  ...]

# %%
client_counter = Counter(clients)
print(f"{len(set(client_counter))} clients")
# Out:
# 37 clients

# %%
jobs = list(df["[Job] Name"].loc[:])
jobs
# Out:
# ['ALPH-2136 ACC AWS Discovery',
#  'ALPH-2136 ACC AWS Discovery',
#  'ALPH-2136 ACC AWS Discovery',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2137 DevOps Engineer ',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2139 Senior Business Analyst',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2140 Software Developer',
#  'ALPH-2141 .Net Engineer',
#  'ALPH-2141 .Net Engineer',
#  'ALPH-2141 .Net Engineer',
#  'ALPH-2141 .Net Engineer',
#  'ALPH-2141 .Net Engineer',
#  'ALPH-2141 .Net Engineer',
#  'ALPH-2141 .Net Engineer',
#  'ALPH-2141 .Net Engineer',
#  'ALPH-2141 .Net Engineer',
#  'ALPH-2141 .Net Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2117 Front-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2118 Back-End Software Engineer',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2120 Senior Site Reliability Engineer ',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2119 Data Engineering',
#  'MMCL-2121 Nexus Modernisation - Lead Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2124 Nexus Modernisation - Backend Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2122 Front-End Software Engineer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'MMCL-2127 Senior Experience Designer',
#  'ASBL-2141 Senior Site Reliability Engineer - Ava Czechowska',
#  'ASBL-2141 Senior Site Reliability Engineer - Ava Czechowska',
#  'ASBL-2141 Senior Site Reliability Engineer - Ava Czechowska',
#  'ASBL-2141 Senior Site Reliability Engineer - Ava Czechowska',
#  'ASBL-2141 Senior Site Reliability Engineer - Ava Czechowska',
#  'ASBL-2141 Senior Site Reliability Engineer - Ava Czechowska',
#  'ASBL-2141 Senior Site Reliability Engineer - Ava Czechowska',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2144 Technical Business Analyst - Grace Wang',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ASBL-2145 Technical Business Analyst - Andrew Wells',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'ANLY-2103 DevOps Support',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'AUTH-2101 Feature Development Squads',
#  'CLPT-1000 Presales',
#  'CLPT-1000 Presales',
#  'CLPT-1000 Presales',
#  'CLPT-1000 Presales',
#  'CLPT-1000 Presales',
#  'CLPT-1000 Presales',
#  'CLPT-1000 Presales',
#  'CLPT-1000 Presales',
#  'CLPT-1000 Presales',
#  'CLPT-1000 Presales',
#  'CLPT-1000 Presales',
#  'CLPT-1000 Presales',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  'CLPT-1001 Internal ',
#  ...]

# %%
job_counter = Counter(jobs)
print(f"{len(set(job_counter))} jobs")
# Out:
# 139 jobs

# %%
staff_counter = Counter(list(df["[Staff] Name"]))
staff_counter
# Out:
# Counter({'Luci Niemand': 136,
#          'Kate Lu': 93,
#          'Omkar Kadam': 89,
#          'Jenny Mullane': 87,
#          'Andrew Lindesay': 79,
#          'Mina Al-Ansari': 73,
#          'Tom Ellis': 68,
#          'Craig McDonald': 67,
#          'Ava Czechowska': 63,
#          'Mike Gatman': 63,
#          'Dan Cornwall': 62,
#          'Caterina Berimballi': 62,
#          'Krishaal Kumar': 57,
#          'David Shepherd': 56,
#          'Prabhu Ramamoorthy': 51,
#          'Malendra Hurbuns': 49,
#          'Simone Boniface': 48,
#          'Thiam Fatt': 46,
#          'Angel Petrovski': 45,
#          'Shi Min Lee': 45,
#          'Asanka Padmakumara': 41,
#          'Hsichen Hsieh': 40,
#          'Terence White': 39,
#          'Michael Magsuci': 39,
#          'Gowri Rudrabhatla': 39,
#          'Connie Pallant': 37,
#          'Mary-anne Stuart-William': 36,
#          'Morne Niemand': 36,
#          'Nicholas Redgwell': 35,
#          'Lesley Walmsley': 35,
#          'Charles Wang': 35,
#          'Ardhra Jacob': 34,
#          'Debbie Murphy': 34,
#          'Jill Nones': 34,
#          'Chris Callaghan': 33,
#          'Dameon Andersen': 32,
#          'Llyle Van Schalkwyk': 32,
#          'Rich Smith': 31,
#          'Bjarne Hansen': 30,
#          'Colm Finn': 30,
#          'Gerry Dassi': 29,
#          'Matthew Berg': 29,
#          'Phil Spenceley': 29,
#          'Tim Ruddell': 28,
#          'Naga Seramsetty': 28,
#          'Heidi Cone': 27,
#          'Megan Robb': 27,
#          'Claudette Chung': 27,
#          'Neil Robson': 27,
#          'David Rawson': 26,
#          'Jason Kang': 26,
#          'Nripendra Pradhananga': 26,
#          'Oliver Liu': 25,
#          'Sang-Woo Kim': 25,
#          'Krishna Caldas': 25,
#          'Colin Henwood': 25,
#          'Mike Nguyen': 24,
#          'Danny Rietkerk': 24,
#          'Alex Zuehlke': 24,
#          'Andrew Barclay': 24,
#          'Andy Mussell': 24,
#          'Ruan van Maarleveld': 24,
#          'Corne Aspeling': 23,
#          'Kevin Zhang': 23,
#          'Andrew Campkin': 23,
#          'Dmitry Oparin': 23,
#          'Weeda Lostitmonton': 23,
#          'Blair Jackson': 22,
#          'Manu Tendulkar': 22,
#          'Colin Sergay': 22,
#          'Matthew Clarke': 22,
#          'Grace Wang': 21,
#          'Sofie Gabriel': 21,
#          'Benigna Mezofi': 21,
#          'Brenda Goudie': 21,
#          'Jonathan Ackerman': 21,
#          'Vivek Chari': 21,
#          'Jason Qu': 21,
#          'Dirk Wessels': 21,
#          'Alexey Pavlenko': 20,
#          'Maxim Kukharev': 20,
#          'Jack Luo': 20,
#          'Ryan Harte': 20,
#          'Bryce Scanlen': 20,
#          'Eddy Kim': 20,
#          'Khush Sethi': 20,
#          'Aleksandra Ovalle': 20,
#          'Karan Ramanathan': 20,
#          'Massimo Berimballi': 20,
#          'Sama Sagar': 20,
#          'Rodd Penney': 20,
#          'Barbara Gray': 20,
#          'Carlos Liu': 20,
#          'Celeste Ormaechea': 20,
#          'Clare Haeney': 20,
#          'Ed Statham': 20,
#          'Edward Weaver': 20,
#          'Inderdip Vraich': 20,
#          'Irina Southwell': 20,
#          'Joel Guevara': 20,
#          'Kelvin Li': 20,
#          'Kenji Yamasaki': 20,
#          'Kiran Rajan': 20,
#          'Manuel Mendes': 20,
#          'Marvin Villahermosa': 20,
#          'Michael Whelan': 20,
#          'Paul Hayter': 20,
#          'Peter Hunter': 20,
#          'Pragathi Singamneni': 20,
#          'Stuart Hilton': 20,
#          'Tracy Carmona': 20,
#          'Wen-Yang Ji': 20,
#          'Yong Que': 20,
#          'Dileep Samala': 20,
#          'Kirill Ivanov': 20,
#          'Yi Liu': 20,
#          'Ben Phear': 20,
#          'Connor Hewett': 20,
#          'Ken Kato': 20,
#          'Sujan Gurung': 20,
#          'Adrian Rivers': 20,
#          'Bert Huang': 20,
#          'Jiaqiu Zhao': 20,
#          'Nikolay Perov': 20,
#          'Sam Vellinga': 20,
#          'Sina Mobeen': 20,
#          'Stuart Massey': 20,
#          'Tejas Kulkarni': 20,
#          'Steve Kelly': 20,
#          'Willard Nyamunokora': 20,
#          'Paul Wavish': 20,
#          'Josh van den Heever': 20,
#          'Mason Blackwood': 20,
#          'Robert Clark': 20,
#          'Shane Henderson': 20,
#          'Max Tang': 19,
#          'Alan McMurtry': 19,
#          "Fran O'Neil": 19,
#          'Ganesan Srinivasan': 19,
#          'Vaughan Walker': 19,
#          'Maheesha Kottegoda': 19,
#          'Boris Guskee': 19,
#          'Gerald Garcia': 19,
#          'Ted Regino': 18,
#          'Abhishek Thapliyal': 18,
#          'Andrew Wells': 18,
#          'Anthony Barr': 18,
#          'Reece Gibbs': 18,
#          'Winnie Sowerby': 18,
#          'Pavel Diatchenko': 18,
#          'Prabhakar Rachamalla': 18,
#          'Mohit Kalra': 18,
#          'Aaron Zhou': 18,
#          'Aaron Ooi': 18,
#          'William Le': 18,
#          'Fedor Vinogradov': 18,
#          'Fletcher Thomas': 18,
#          'Dhaval Tanna': 18,
#          'Karthik Kreen Krishnan': 18,
#          'Karo Liang': 18,
#          'Victor Mingueza': 18,
#          'Samuel Grospe': 18,
#          'Paul McDonnell': 18,
#          'Michael Owen': 18,
#          'Varun Ghaswala': 18,
#          'Zoe Xu': 18,
#          'Riel Fabillar': 18,
#          'Jenny Chiu': 17,
#          'Kris Rayana': 17,
#          'Robin Southgate': 17,
#          'Dennis Sosnoski': 17,
#          'Alister Wright': 16,
#          'Wayne Goh': 16,
#          'Charlotte Cox': 15,
#          'Tao Lin': 15,
#          'Bhawna Malhotra': 15,
#          'Lana Shatonova': 15,
#          'Chris Hoolihan': 14,
#          'Daron Robinson': 14,
#          'Lux Liu': 13,
#          'Miriam Walker': 12,
#          'Andrew Martin': 11,
#          'Brian Saunders': 10,
#          'Eran Moshayov': 10,
#          'Stuart Chen': 10,
#          'Bryan Stephens': 9,
#          'Joseph Dignadice': 9,
#          'Andrew Simpson': 9,
#          'Troy Wing': 9,
#          'Natasha Pearce': 8,
#          'Ekamban Chokkappan': 8,
#          'Amin Zabihi': 7,
#          'Cheryl Dwyer': 6,
#          'Alex Amsler': 6,
#          'Thomas Vercoutre': 6,
#          'Lauren Simpson': 5,
#          'Robin Bygrave': 5,
#          'Craig Forster': 5,
#          'Marie Tamplin': 4,
#          'Matt Millar': 4,
#          'Hamid Sedghinezhad': 4,
#          'Bain Hollister': 3,
#          'Stephen Dickens': 2,
#          'Sreeram Sreedharan': 2,
#          'See Wong': 1,
#          'Phil Pietersen': 1})

# %%
print(f"{len(set(staff_counter))} staff")
# Out:
# 206 staff

# %%
nodes = set(client_counter).union(set(job_counter)).union(set(staff_counter))
print(f"{len(nodes)} nodes will be added")
# Out:
# 382 nodes will be added

# %%
worked_on_connections = max([len(staff_counter),len(client_counter)])
worked_on_connections
# Out:
# 206

# %%
billed_time_connections = max([len(staff_counter),len(job_counter)])
billed_time_connections
# Out:
# 206

# %%
has_job_connections = max([len(client_counter),len(job_counter)])
has_job_connections
# Out:
# 139

# %%
total_connections = worked_on_connections + billed_time_connections + has_job_connections
total_connections
# Out:
# 551
